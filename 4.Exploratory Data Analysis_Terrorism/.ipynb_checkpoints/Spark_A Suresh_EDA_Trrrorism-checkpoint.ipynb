# %% [markdown]
# <h2 style="color:blue" align="left"> Task 4: Exploratory Data Analysis on dataset 'Global Terrorism' </h2>
#
#
# ## Objective
#
# - Perform **'Exploratory Data Analysis'** on dataset **"Global Terrorism"**.
#
#
# - As a **security / defense analyst**, try to find out the **hot zone terrorism**.
#
#
# - What all security issues and insights you can derive by EDA?

# %% [markdown]
# ## Data Science Business Analytics Internship
# ### GRIP @ The Sparks Foundaton
# <h2 style=color:green align="left"> BY: Anuganti Suresh </h2>

# %% [markdown]
# ----------------------------------

# %% [markdown]
# <h2 style="color:blue" align="left"> 1. Import Necessary Libraries </h2>

# %%
# Read data
import numpy as np                           # Linear Algebra (calculate the mean and standard deviation)
import pandas as pd                          # manipulate data, data processing, load csv file I/O (e.g. pd.read_csv)

# Visualization
import matplotlib.pyplot as plt              # Visualization using matplotlib
# %matplotlib inline
import seaborn as sns                        # Visualization using seaborn

# style
plt.style.use("fivethirtyeight")             # Set Graphs Background style using matplotlib
sns.set_style("darkgrid")                    # Set Graphs Background style using seaborn

import warnings                              # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
# for interactivity
from ipywidgets import interact

# %% [markdown]
# <h2 style=color:blue align="left"> 2. EDA(Exploratory Data Analysis) </h2>

# %% [markdown]
# <h2 style=color:green align="left"> a. Understand the data </h2>

# %%
# Loading the dataset
df = pd.read_csv("globalterrorismdb_0718dist.csv", low_memory=False, encoding='latin-1')
pd.set_option('max_columns', 135)

# %%
# import first & last 5 rows
display(df.head())
display(df.tail())
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %%
# checking dimension (num of rows and columns) of dataset
print("Terrorism shape (Rows, Columns):", df.shape)
# Out:
# Terrorism shape (Rows, Columns): (181691, 135)

# %%
# Checking for any duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# check dataframe structure like columns and its counts, datatypes & Null Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Checking for column names
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
# Gives number of data points in each variable
df.count()
# Out:
# eventid       181691
# iyear         181691
# imonth        181691
# iday          181691
# approxdate      9239
#                ...
# INT_LOG       181691
# INT_IDEO      181691
# INT_MISC      181691
# INT_ANY       181691
# related        25038
# Length: 135, dtype: int64

# %%
# Looking for short description of dataset
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# <h2 style=color:green align="left"> b. Clean the data </h2>

# %% [markdown]
# ### i) Missing Values

# %%
# Checking for missing data
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# - There are in fact lots of missing values

# %%
# Checking the percentage of missing values
missing_percentage = df.isnull().sum()*100 /len(df)
print(missing_percentage)
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df.dropna(thresh=180000, axis=1,inplace=True)

# %% [markdown]
# <h2 style=color:green align="left"> c. Analysis of Relationship between variables </h2>

# %%
df.corr()
# Out:
#               eventid     iyear    imonth      iday  extended   country  \
# eventid      1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear        0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth       0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday         0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended     0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country     -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region       0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# specificity  0.030641  0.030626  0.003621 -0.006991  0.057897 -0.084599
# vicinity     0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# crit1        0.002019  0.001995  0.001568  0.011434 -0.015029 -0.006646
# crit2        0.026215  0.026211  0.001734 -0.002702  0.001249 -0.038480
# crit3       -0.016789 -0.016784  0.000176 -0.004889  0.048533 -0.040288
# doubtterr    0.298888  0.298920 -0.012477  0.002395  0.011638  0.038304
# multiple     0.093720  0.093736 -0.004422 -0.000395 -0.013440 -0.022218
# success     -0.082972 -0.082963 -0.002845 -0.011802  0.073233 -0.037827
# suicide      0.137743  0.137736  0.003071  0.003593 -0.033961 -0.050360
# attacktype1  0.074173  0.074153  0.006705 -0.005333  0.272272 -0.021384
# targtype1    0.079080  0.079082 -0.000948 -0.000052  0.011613 -0.019703
# natlty1     -0.019084 -0.019068 -0.004838  0.003845  0.013609  0.600020
# guncertain1  0.040647  0.040656 -0.004460 -0.002186  0.033464 -0.010369
# individual   0.017939  0.017944 -0.001661 -0.003788 -0.008929  0.027918
# weaptype1   -0.011716 -0.011737  0.007863 -0.003019  0.207802 -0.023708
# property    -0.278927 -0.278916 -0.005816 -0.003903 -0.002096  0.032051
# ishostkid   -0.010146 -0.010159  0.003397  0.004077  0.326351 -0.013335
# INT_LOG     -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO    -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC    -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY     -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#                region  specificity  vicinity     crit1  ...   natlty1  \
# eventid      0.401371     0.030641  0.070646  0.002019  ... -0.019084
# iyear        0.401384     0.030626  0.070659  0.001995  ... -0.019068
# imonth      -0.002999     0.003621 -0.004501  0.001568  ... -0.004838
# iday         0.009710    -0.006991 -0.005367  0.011434  ...  0.003845
# extended     0.038389     0.057897  0.017784 -0.015029  ...  0.013609
# country      0.148597    -0.084599 -0.012291 -0.006646  ...  0.600020
# region       1.000000    -0.084198  0.073678  0.025521  ...  0.149821
# specificity -0.084198     1.000000 -0.049855  0.014323  ... -0.034336
# vicinity     0.073678    -0.049855  1.000000  0.003330  ...  0.012976
# crit1        0.025521     0.014323  0.003330  1.000000  ... -0.009719
# crit2       -0.013163     0.000943 -0.000534 -0.008984  ... -0.019780
# crit3       -0.010175    -0.072680 -0.054995 -0.040589  ... -0.083928
# doubtterr    0.086832     0.041980  0.034820 -0.059065  ...  0.039491
# multiple     0.011963     0.036660 -0.011645  0.030311  ... -0.013767
# success     -0.030909     0.015301 -0.002223 -0.010733  ... -0.007157
# suicide      0.112672    -0.031921  0.008352  0.019039  ... -0.009207
# attacktype1  0.007642     0.056041  0.006504  0.027544  ...  0.013769
# targtype1    0.041396     0.044518  0.024644 -0.040026  ... -0.034994
# natlty1      0.149821    -0.034336  0.012976 -0.009719  ...  1.000000
# guncertain1 -0.022758    -0.009168  0.031177  0.013568  ... -0.004394
# individual  -0.059963    -0.022631 -0.011986 -0.025591  ...  0.030472
# weaptype1    0.013257     0.064587  0.001496  0.029257  ... -0.008537
# property    -0.183279     0.028111 -0.019811 -0.007595  ... -0.000624
# ishostkid   -0.023058     0.016048  0.004626 -0.015465  ...  0.002085
# INT_LOG     -0.082584     0.073022  0.014487  0.089973  ...  0.039458
# INT_IDEO    -0.071917     0.071333  0.015119  0.089888  ...  0.050055
# INT_MISC     0.043139    -0.019197 -0.008232  0.015692  ...  0.360373
# INT_ANY     -0.047900     0.061389  0.010325  0.082288  ...  0.147251
#
#              guncertain1  individual  weaptype1  property  ishostkid  \
# eventid         0.040647    0.017939  -0.011716 -0.278927  -0.010146
# iyear           0.040656    0.017944  -0.011737 -0.278916  -0.010159
# imonth         -0.004460   -0.001661   0.007863 -0.005816   0.003397
# iday           -0.002186   -0.003788  -0.003019 -0.003903   0.004077
# extended        0.033464   -0.008929   0.207802 -0.002096   0.326351
# country        -0.010369    0.027918  -0.023708  0.032051  -0.013335
# region         -0.022758   -0.059963   0.013257 -0.183279  -0.023058
# specificity    -0.009168   -0.022631   0.064587  0.028111   0.016048
# vicinity        0.031177   -0.011986   0.001496 -0.019811   0.004626
# crit1           0.013568   -0.025591   0.029257 -0.007595  -0.015465
# crit2          -0.003619    0.003311  -0.008549 -0.002711   0.001313
# crit3           0.057764    0.016806   0.018320  0.013345   0.044759
# doubtterr       0.060559    0.008943  -0.130111 -0.112490  -0.030694
# multiple        0.021972    0.004756   0.032537 -0.025458  -0.047815
# success         0.024725   -0.013868  -0.008178 -0.036876   0.044760
# suicide        -0.000819    0.000775  -0.039928 -0.073382  -0.021752
# attacktype1     0.013182    0.016438   0.658954  0.031976   0.176862
# targtype1       0.012865    0.005267   0.019846  0.004897   0.010290
# natlty1        -0.004394    0.030472  -0.008537 -0.000624   0.002085
# guncertain1     1.000000   -0.000614   0.005953 -0.027394   0.016736
# individual     -0.000614    1.000000   0.005754  0.006625   0.002133
# weaptype1       0.005953    0.005754   1.000000  0.018999   0.139865
# property       -0.027394    0.006625   0.018999  1.000000   0.018890
# ishostkid       0.016736    0.002133   0.139865  0.018890   1.000000
# INT_LOG         0.241616   -0.048526   0.072941  0.052445   0.035463
# INT_IDEO        0.239388   -0.048542   0.074702  0.047609   0.036875
# INT_MISC       -0.004986    0.005490  -0.011652  0.022058   0.017453
# INT_ANY         0.211408   -0.037488   0.084257  0.065701   0.043566
#
#               INT_LOG  INT_IDEO  INT_MISC   INT_ANY
# eventid     -0.143600 -0.133252 -0.077852 -0.175605
# iyear       -0.143601 -0.133253 -0.077847 -0.175596
# imonth      -0.002302 -0.002034 -0.002554 -0.006336
# iday        -0.001540 -0.001621 -0.002027 -0.001199
# extended     0.071768  0.075147  0.027335  0.080767
# country      0.069904  0.067564  0.207281  0.153118
# region      -0.082584 -0.071917  0.043139 -0.047900
# specificity  0.073022  0.071333 -0.019197  0.061389
# vicinity     0.014487  0.015119 -0.008232  0.010325
# crit1        0.089973  0.089888  0.015692  0.082288
# crit2       -0.024153 -0.023829 -0.012980 -0.027752
# crit3       -0.134557 -0.138251 -0.036112 -0.130216
# doubtterr    0.230356  0.231789  0.022374  0.168947
# multiple     0.124327  0.126013 -0.027084  0.095019
# success      0.059875  0.059183 -0.014906  0.038245
# suicide      0.058735  0.065882 -0.000879  0.057241
# attacktype1  0.075002  0.077225  0.010632  0.088711
# targtype1   -0.056550 -0.058010 -0.043492 -0.054497
# natlty1      0.039458  0.050055  0.360373  0.147251
# guncertain1  0.241616  0.239388 -0.004986  0.211408
# individual  -0.048526 -0.048542  0.005490 -0.037488
# weaptype1    0.072941  0.074702 -0.011652  0.084257
# property     0.052445  0.047609  0.022058  0.065701
# ishostkid    0.035463  0.036875  0.017453  0.043566
# INT_LOG      1.000000  0.996211  0.052537  0.891051
# INT_IDEO     0.996211  1.000000  0.082014  0.893811
# INT_MISC     0.052537  0.082014  1.000000  0.252193
# INT_ANY      0.891051  0.893811  0.252193  1.000000
#
# [28 rows x 28 columns]

# %%
df.shape
# Out:
# (181691, 39)

# %% [markdown]
# <h2 style=color:green align="left"> d. Data Visualisation </h2>

# %%
# Let's see in which year, attacks happened most number of times

plt.rcParams['figure.figsize']=15,11
sns.countplot(y=df['iyear'], palette='inferno')

plt.xlabel('Number of attacks', fontsize=20, fontweight='bold')
plt.ylabel('Attack Year', fontsize=20, fontweight='bold')

plt.title('Trend of increase in Terror from 1970 to 2017', fontweight="bold", size=25)

plt.xticks(fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %% [markdown]
# - 2014 happened most attacks

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='iyear',hue='success',data=df)

plt.xlabel('Attack Year', fontsize=20, fontweight='bold')
plt.ylabel('Number of attacks', fontsize=20, fontweight='bold')

plt.title('Trend of increase in Terror from 1970 to 2017', fontweight="bold", size=25)

plt.xticks(rotation=60, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %%
df['region_txt'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: region_txt, dtype: int64

# %%
#let's check which region is affected by terrorism in each year
@interact

def attack_year(year=list(df['iyear'].unique())):
    a = df[df['iyear']==year]
    return sns.countplot(y=a['region_txt'], palette='viridis')

# %%
#let's check which countries are affected more from each region
@interact
def country_name(region=list(df['region'].unique())):
    a=df[(df['region']==region)]
    a=pd.DataFrame(a['country'].value_counts())
    return a.style.background_gradient(cmap='plasma')
# Out:
# <style  type="text/css" >
#     #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow0_col0 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow1_col0 {
#             background-color:  #ac2694;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow2_col0 {
#             background-color:  #a72197;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow3_col0 {
#             background-color:  #2f0596;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow4_col0 {
#             background-color:  #260591;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow5_col0 {
#             background-color:  #1d068e;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow6_col0 {
#             background-color:  #19068c;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow7_col0 {
#             background-color:  #16078a;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow8_col0 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow9_col0 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow10_col0 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow11_col0 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow12_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow13_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow14_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow15_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow16_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow17_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow18_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow19_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow20_col0 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }</style><table id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row0" class="row_heading level0 row0" >61</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow0_col0" class="data row0 col0" >5320</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row1" class="row_heading level0 row1" >83</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow1_col0" class="data row1 col0" >2050</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row2" class="row_heading level0 row2" >145</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow2_col0" class="data row2 col0" >1970</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row3" class="row_heading level0 row3" >88</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow3_col0" class="data row3 col0" >323</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row4" class="row_heading level0 row4" >87</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow4_col0" class="data row4 col0" >213</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row5" class="row_heading level0 row5" >156</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow5_col0" class="data row5 col0" >127</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row6" class="row_heading level0 row6" >58</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow6_col0" class="data row6 col0" >90</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row7" class="row_heading level0 row7" >49</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow7_col0" class="data row7 col0" >67</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row8" class="row_heading level0 row8" >81</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow8_col0" class="data row8 col0" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row9" class="row_heading level0 row9" >100</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow9_col0" class="data row9 col0" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row10" class="row_heading level0 row10" >51</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow10_col0" class="data row10 col0" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row11" class="row_heading level0 row11" >207</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow11_col0" class="data row11 col0" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row12" class="row_heading level0 row12" >127</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow12_col0" class="data row12 col0" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row13" class="row_heading level0 row13" >22</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow13_col0" class="data row13 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row14" class="row_heading level0 row14" >17</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow14_col0" class="data row14 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row15" class="row_heading level0 row15" >80</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow15_col0" class="data row15 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row16" class="row_heading level0 row16" >20</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow16_col0" class="data row16 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffalevel0_row17" class="row_heading level0 row17" >57</th>
#                         <td id="T_cf632662_408f_11eb_b3ea_3c77e6dc4ffarow17_col0" class="data row17 col0" >3</td>
#             </tr>
#             <tr>

# %%
#let's check which cities attacked most of the time from each country
@interact
def city_name(country=list(df['country'].unique())):
    a=df[df['country']==country]
    a=pd.DataFrame(a['city'].value_counts().head(10))
    return a.style.background_gradient(cmap='cool')
# Out:
# <style  type="text/css" >
#     #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow0_col0 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow1_col0 {
#             background-color:  #21deff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow2_col0 {
#             background-color:  #10efff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow3_col0 {
#             background-color:  #05faff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow4_col0 {
#             background-color:  #05faff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow5_col0 {
#             background-color:  #05faff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow6_col0 {
#             background-color:  #05faff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow7_col0 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow8_col0 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow9_col0 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }</style><table id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row0" class="row_heading level0 row0" >Santo Domingo</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow0_col0" class="data row0 col0" >48</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row1" class="row_heading level0 row1" >Esperanza</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow1_col0" class="data row1 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row2" class="row_heading level0 row2" >Salcedo</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow2_col0" class="data row2 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row3" class="row_heading level0 row3" >Santiago de los Caballeros</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow3_col0" class="data row3 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row4" class="row_heading level0 row4" >San Cristobal</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow4_col0" class="data row4 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row5" class="row_heading level0 row5" >San Pedro de Macoris</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow5_col0" class="data row5 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row6" class="row_heading level0 row6" >Nagua</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow6_col0" class="data row6 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row7" class="row_heading level0 row7" >Bonao</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow7_col0" class="data row7 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row8" class="row_heading level0 row8" >Hostos</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow8_col0" class="data row8 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffalevel0_row9" class="row_heading level0 row9" >San Francisco de Macoris</th>
#                         <td id="T_deb8617a_408f_11eb_bc66_3c77e6dc4ffarow9_col0" class="data row9 col0" >2</td>
#             </tr>
#     </tbody></table>

# %%
plt.figure(figsize=(15,6))

sns.countplot(x='region_txt',data=df)

plt.xlabel('Region-wise', fontsize=20, fontweight='bold')
plt.ylabel('Number of attacks', fontsize=20, fontweight='bold')

plt.title('Total number of attacks Region-wise', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %% [markdown]
# - Region-wise **Middle East & NorthAfrica,South Asia** are hot terror zones where as **Central Asia** has least number of terror attack

# %%
df['country_txt'].value_counts()[:20]
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: country_txt, dtype: int64

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)

plt.xlabel('Country', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total number of attacks Country-wise', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %% [markdown]
# - As we can clearly see that **Iraq** has the **higgest number of terror attack** and **Egypt** has lower

# %%
df['gname'].value_counts()[:20]
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# National Liberation Army of Colombia (ELN)           1561
# Tehrik-i-Taliban Pakistan (TTP)                      1351
# Palestinians                                         1125
# Houthi extremists (Ansar Allah)                      1062
# Al-Qaida in the Arabian Peninsula (AQAP)             1020
# Name: gname, dtype: int64

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['gname'].value_counts()[:20].index,y=df['gname'].value_counts()[:20].values)

plt.xlabel('Country', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total number of attacks group-wise', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %% [markdown]
# - From the above data we can see that some **unknown groups and Talian,ISIL** etc are the **major terrorist groups**

# %%
df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['attacktype1_txt'].value_counts().index,y=df['attacktype1_txt'].value_counts().values)

plt.xlabel('Attack type', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total count of Attack types', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %% [markdown]
# - From the above data the major destructive attacktypes are **Bombing/Explosion, Armed assault, Assassination** amd many more

# %%
df['targtype1_txt'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
plt.figure(figsize=(15,6))

sns.barplot(x=df['targtype1_txt'].value_counts().index,y=df['targtype1_txt'].value_counts().values)

plt.xlabel('Target type', fontsize=20, fontweight='bold')
plt.ylabel('Total attack counts', fontsize=20, fontweight='bold')

plt.title('Total count of attack on differnt target type', fontweight="bold", size=25)

plt.xticks(rotation=90, fontweight="bold", size=15)
plt.yticks(fontweight="bold", size=15)

plt.show()

# %% [markdown]
# - Attackers target the people who are **private citizens and have property, Military person, police, Government(General) and many more**

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Iraq ranked first on the global terrorism for their terrorist activity followed by Pakistan, Afganistan, India, and so on
#
#
# - Most targeted areas are private citizens and property, military, police, and so on
#
#
# - Global terror attack deaths rose sharply starting year 2011
#
#
# - In conclusion with the ranking, Iraq suffered from most terrorist attacks in 2014, with  the most deaths in that year
